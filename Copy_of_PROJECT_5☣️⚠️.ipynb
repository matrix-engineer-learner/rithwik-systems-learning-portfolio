# %% [markdown]
# <a href="https://colab.research.google.com/github/matrix-engineer-learner/rithwik-systems-learning-portfolio/blob/main/Copy_of_PROJECT_5%E2%98%A3%EF%B8%8F%E2%9A%A0%EF%B8%8F.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title 🏢 Project 4: Automated Nuclear Lockdown Simulator
# @markdown Tweak the security and critical risk metric inputs below, then click Play (▶️) to run the simulation!

# 1. INPUT DATA STREAMS (Left side of your diagram)
Sensor_Asset_ID = "CORE-UNIT-7B" #@param {type:"string"}
Thermal_Risk_Metric_Score = 78 #@param {type:"slider", min:0, max:100, step:1}
Is_Emergency_Condition_Active = True #@param {type:"boolean"}
Is_Critical_Condition_Active = True #@param {type:"boolean"}

print(f"📥 [INGESTION NODE] Evaluating critical streams for: {Sensor_Asset_ID}")
print(f"📊 Cognitive Thermal Risk Score: {Thermal_Risk_Metric_Score}/100\n")

# 2. PROCESSING ENGINE (Matching your central decision gates)
print("🧠 Activating System Infrastructure Decision Tree...")

# Logic path based directly on your diagram branches and color codes
if Thermal_Risk_Metric_Score < 40:
    final_protocol = "🍏 4A RPA: LOG COMPLIANCE RISK METRICS (Nominal Operational Status)"
elif 40 <= Thermal_Risk_Metric_Score < 60:
    final_protocol = "💧 4B RPA: TRIGGER COOLING SYSTEM UPGRADES (Minor Variance Detected)"
else:
    # Evaluating severe condition pathways (Orange/Red sections)
    if Is_Emergency_Condition_Active and Is_Critical_Condition_Active:
        final_protocol = "☢️ 5.RPA: TRIGGER NUCLEAR LOCKDOWN PROTOCOL\n⚠️ EMERGENCY LEVEL 5: Core infrastructure isolating immediately."
    elif Is_Emergency_Condition_Active and not Is_Critical_Condition_Active:
        final_protocol = "🚨 4A RPA: ACTIVE EMERGENCY DEPLOYMENT (Immediate Personnel Notification)"
    else:
        final_protocol = "🛡️ 4B RPA: INITIALIZE SECTOR DECONTAMINATION (Preventative Containment Active)"

print("-" * 75)
print(f"📤 TRIGGERED AUTOMATION PROTOCOL:\n{final_protocol}")
print("-" * 75)

# %%
# @title 🧭 Project 4: Quantum Reactor Core Radar Monitor
# @markdown Configure the live telemetry inputs on the right, then hit the simulation button!

import ipywidgets as widgets
from IPython.display import display, HTML, clear_output
import time

# 1. SETUP THE SCIFI DESIGN CONTROL INTERFACE
Sensor_Asset_ID = widgets.Text(value='CORE-UNIT-7B', description='🛰️ NODE ID:')
Thermal_Risk = widgets.IntSlider(value=78, min=0, max=100, step=1, description='🌡️ RISK IDX:')
Is_Emergency = widgets.Checkbox(value=True, description='🚨 ACTIVE EMERGENCY PROTOCOL')
Is_Critical = widgets.Checkbox(value=True, description='⚠️ CRITICAL PRESSURE BOUNDARY')

# 2. HYDRO-CYBER RADAR ENGINE
def run_radar_simulation(b):
    with output_area:
        clear_output(wait=True)

        # Phase 1: Sci-Fi Ingestion Animation
        display(HTML(f'''
            <div style="font-family: 'Courier New', monospace; padding: 15px; border-radius: 4px; background-color: #0b0f19; color: #00f0ff; border: 1px solid #00f0ff; margin-bottom: 15px; box-shadow: 0 0 10px #00f0ff33;">
                <span style="animation: blink 0.8s infinite; font-weight: bold; margin-right: 10px;">⚡</span> [SYS_LOG] ESTABLISHING TELEMETRY CONNECTION TO LINK_NODE::{Sensor_Asset_ID.value}...
                <div style="width: 100%; background-color: #05070c; border: 1px solid #00f0ff; margin-top: 8px; height: 6px; position: relative;">
                    <div style="background-color: #00f0ff; height: 100%; width: 0%; animation: matrix_load 1.4s forwards linear; box-shadow: 0 0 8px #00f0ff;"></div>
                </div>
            </div>
            <style>
                @keyframes matrix_load {{ to {{ width: 100%; }} }}
                @keyframes blink {{ 0%, 100% {{ opacity: 0; }} 50% {{ opacity: 1; }} }}
            </style>
        '''))
        time.sleep(1.4)

        # Calculate conditions
        score = Thermal_Risk.value
        emerg = Is_Emergency.value
        crit = Is_Critical.value
        core_health = 100 - score

        # Rule Branch Evaluation from your blueprint
        if score < 40:
            status, color, shadow, text = "NOMINAL OPERATIONAL CALIBRATION", "#00f0ff", "#00f0ff", "🍏 4A RPA: LOG COMPLIANCE RISK METRICS<br>>> Operational boundaries running safely inside baseline grid configurations."
        elif 40 <= score < 60:
            status, color, shadow, text = "THERMAL INJECTION WARNING", "#ffb703", "#ffb703", "💧 4B RPA: TRIGGER AUXILIARY COOLING GRID INJECTION<br>>> Relaying immediate signal vectors to balance primary core load variables."
        else:
            if emerg and crit:
                status, color, shadow, text = "CRITICAL INDUSTRIAL LOCKDOWN", "#ff0054", "#ff0054", "☢️ 5.RPA: TRIGGER STRUCTURAL LOCKDOWN PROTOCOL<br>⚠️ DIRECTIVE COMPULSORY: Level 5 automation isolating core infrastructure containment immediately."
            elif emerg and not crit:
                status, color, shadow, text = "ACTIVE EMERGENCY OVERRIDE", "#ff5400", "#ff5400", "🚨 4A RPA: ACTIVE EMERGENCY DEPLOYMENT<br>>> Immediate remote tracking protocols sent to regional duty team."
            else:
                status, color, shadow, text = "SECTOR DECONTAMINATION MATRIX", "#ccff33", "#ccff33", "🛡️ 4B RPA: INITIALIZE ACCELERATED DECONTAMINATION<br>>> Sealing auxiliary ventilation matrices automatically."

        # Phase 2: Render Custom Cyber Radar Monitor Dashboard
        display(HTML(f'''
            <div style="font-family: 'Courier New', monospace; padding: 25px; border-radius: 4px; background-color: #070a12; color: #e0e6ed; border: 2px solid {color}; box-shadow: 0 0 25px {shadow}33; background-image: linear-gradient(#0c1220 1px, transparent 1px), linear-gradient(90deg, #0c1220 1px, transparent 1px); background-size: 20px 20px;">

                <!-- Header Monitor Bar -->
                <div style="display: flex; justify-content: space-between; align-items: center; border-bottom: 2px dashed #1a233a; padding-bottom: 12px; margin-bottom: 20px;">
                    <span style="font-size: 11px; color: #5f759e; font-weight: bold; letter-spacing: 1px;">⚙️ CENTRAL CORE CORE-MONITOR PROTOCOL v4.0</span>
                    <span style="color: {color}; font-weight: bold; font-size: 12px; text-shadow: 0 0 5px {color};">[ {status} ]</span>
                </div>

                <!-- Core Status Layout Grid -->
                <div style="display: flex; align-items: center; background: #0c1222; padding: 20px; border: 1px dashed #1a233a; border-radius: 4px;">
                    <div style="font-size: 38px; margin-right: 25px; animation: alert_pulse 1s infinite alternate; text-shadow: 0 0 10px {color};">⚠️</div>
                    <div style="flex-grow: 1;">
                        <h4 style="margin: 0 0 6px 0; color: {color}; letter-spacing: 0.5px; font-size: 15px;">AUTOMATED OVERRIDE TRIGGERED:</h4>
                        <p style="margin: 0; font-size: 13px; color: #b0c2de; line-height: 1.5; font-weight: 500;">{text}</p>
                    </div>
                </div>

                <!-- Live Bar Matrix Graph Metric -->
                <div style="margin-top: 25px;">
                    <div style="display: flex; justify-content: space-between; font-size: 11px; color: #5f759e; font-weight: bold; margin-bottom: 6px;">
                        <span>🔋 SIMULATED CORE HEALTH STABILITY MATRIX:</span>
                        <span style="color: {color}; font-weight: bold;">{core_health}% STABLE</span>
                    </div>
                    <div style="width: 100%; background-color: #0b111e; border: 1px solid #1a233a; height: 14px; padding: 2px;">
                        <div style="background-color: {color}; height: 100%; width: {core_health}%; box-shadow: 0 0 10px {color}; transition: width 0.4s;"></div>
                    </div>
                </div>

                <!-- Footer Audit Logs -->
                <div style="margin-top: 20px; padding-top: 15px; border-top: 2px dashed #1a233a; font-size: 11px; color: #5f759e; display: flex; justify-content: space-between;">
                    <span>SYS_TARGET :: {Sensor_Asset_ID.value}</span>
                    <span>THERMAL_INDEX_VALUE :: {score}/100</span>
                </div>
            </div>

            <style>
                @keyframes alert_pulse {{ from {{ transform: scale(1); opacity: 0.7; }} to {{ transform: scale(1.08); opacity: 1; }} }}
            </style>
        '''))

# 3. CONSOLE INTERACTION COMMAND INTERFACE
run_btn = widgets.Button(description="📡 INITIALIZE CORE MONITOR", button_style='', layout=widgets.Layout(margin='20px 0 0 0', width='280px'))
run_btn.style.button_color = '#00f0ff'
run_btn.on_click(run_radar_simulation)
output_area = widgets.Output()

# Build the layout grid
ui_box = widgets.VBox([Sensor_Asset_ID, Thermal_Risk, Is_Emergency, Is_Critical, run_btn])
display(ui_box, output_area)
# Out:
# ...
# Output()
